# %%
# %% libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from io import StringIO 
from IPython.display import Image 
from pydot import graph_from_dot_data

# %%
data = pd.read_csv('C:\\Users\\DKici\\Documents\\PricingPromo\\data\\Promo_Pricing_Combined_Data\\pricing_promo_2019_2021_campaign_covid_sales.csv')
data = data.drop(columns = "Unnamed: 0")
data.head(2)
# Out:
#          Date  Amount of Employee pricing % off  off Particular Item?  \
# 0  2019-03-01                                 0                     0
# 1  2019-03-02                                 0                     0
#
#    Amount of % Off Particular Item  Location Specific?  off 1st item?  \
# 0                                0                   0              0
# 1                                0                   0              0
#
#    Amount of % off 1st item  off conditional?  Amount of $ off conditional  \
# 0                         0                 1                            0
# 1                         0                 1                            0
#
#    Amount of % off conditional  ...  Saskatchewan_C1_School closing_3.0  \
# 0                           25  ...                                 0.0
# 1                           25  ...                                 0.0
#
#    Saskatchewan_C2_Workplace closing_1.0  \
# 0                                    0.0
# 1                                    0.0
#
#    Saskatchewan_C2_Workplace closing_2.0  \
# 0                                    0.0
# 1                                    0.0
#
#    Saskatchewan_C2_Workplace closing_3.0  \
# 0                                    0.0
# 1                                    0.0
#
#    Saskatchewan_C6_Stay at home requirements_1.0  WrittenSales     Margin  \
# 0                                            0.0     267388.65  114438.41
# 1                                            0.0     668799.75  302135.49
#
#    Traffic  FinancedAmount  StoreOpen
# 0   1826.5      3804921.27       28.0
# 1   3567.5      5347859.81       27.0
#
# [2 rows x 106 columns]

# %%
for i in range(len(data.columns)):
    print(i,data.columns[i])
# Out:
# 0 Date
# 1 Amount of Employee pricing % off
# 2 off Particular Item?
# 3 Amount of % Off Particular Item
# 4 Location Specific?
# 5 off 1st item?
# 6 Amount of % off 1st item
# 7 off conditional?
# 8 Amount of $ off conditional
# 9 Amount of % off conditional
# 10 off HomeStore Specials?
# 11 Amount of % Off Homestore Specials
# 12 Amount of % off Reg Price Living, Dining, amd M. Bedroom
# 13 % off reg. price living, dining, and m. bedroom?
# 14 off rest of purchase?
# 15 Amount of % off rest of purchase
# 16 off sectionals?
# 17 Amount % off sectionals
# 18 amount of % off sofa w/ full price loveseat
# 19 sofa w full-price loveseat?
# 20 Amount of % Accessories
# 21 Add. % off CLA?
# 22 Amount of % Off CLA
# 23 off JUV?
# 24 Amount of % Off JUV
# 25 off OTB (occasional tables)?
# 26 Amount of % Off OTB(occasional tables)
# 27  Financing?
# 28 Amount of % When Financing
# 29 Amount of % With Rest Test
# 30 Amount % Off at 090
# 31 Amount % off in AB
# 32 Amount % off in GTA
# 33 Amount % off in MB
# 34 Amount % Savings over $2499
# 35 Amount of %  Savings for $1499 or more
# 36 Amount of % Savings over $2000
# 37 Black Friday?
# 38 BMSM?
# 39 Canada Day
# 40 Clearance (CLA)
# 41 Doorcrashers
# 42 Easter Weekend
# 43 First Item?
# 44 Flash
# 45 Flash Items Only
# 46 Family Spaces
# 47 off reg priced furniture?
# 48 Amount of off reg priced furniture
# 49 High Impact
# 50 Item and Price (I&P)
# 51 Matress Deal
# 52 Flyer continues
# 53 No flyer items
# 54 No Flyers
# 55 No promo items
# 56 Online Only
# 57 OR
# 58  Percent  Amount
# 59 Percent  discount?
# 60 simple event
# 61 Prospect Event
# 62 Red Tag Sale
# 63 Rest Test
# 64 Separate item selections
# 65 Amount of x GST Savings
# 66 Amount x Tax Savings
# 67 Tax
# 68 Week 1
# 69 Week 2
# 70 Week 3
# 71 Week 4
# 72 Week 5
# 73 Wrap
# 74 $X off with $Y
# 75 X% on orders over $Y
# 76 $X off over $Y
# 77 nth_day_of_week
# 78 nth_day_of_month
# 79 month_of_the_year
# 80 Ontario_C1_School closing_1.0
# 81 Ontario_C1_School closing_2.0
# 82 Ontario_C1_School closing_3.0
# 83 Ontario_C2_Workplace closing_1.0
# 84 Ontario_C2_Workplace closing_2.0
# 85 Ontario_C2_Workplace closing_3.0
# 86 Ontario_C6_Stay at home requirements_1.0
# 87 Ontario_C6_Stay at home requirements_2.0
# 88 Manitoba_C1_School closing_1.0
# 89 Manitoba_C1_School closing_2.0
# 90 Manitoba_C2_Workplace closing_1.0
# 91 Manitoba_C2_Workplace closing_2.0
# 92 Manitoba_C2_Workplace closing_3.0
# 93 Manitoba_C6_Stay at home requirements_1.0
# 94 Manitoba_C6_Stay at home requirements_2.0
# 95 Saskatchewan_C1_School closing_2.0
# 96 Saskatchewan_C1_School closing_3.0
# 97 Saskatchewan_C2_Workplace closing_1.0
# 98 Saskatchewan_C2_Workplace closing_2.0
# 99 Saskatchewan_C2_Workplace closing_3.0
# 100 Saskatchewan_C6_Stay at home requirements_1.0
# 101 WrittenSales
# 102 Margin
# 103 Traffic
# 104 FinancedAmount
# 105 StoreOpen

# %%
# data = data.drop(columns = data.columns[80:-4], axis = 1)
# data.head()

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Columns: 106 entries, Date to StoreOpen
# dtypes: float64(26), int64(79), object(1)
# memory usage: 858.9+ KB

# %%
feature = "WrittenSales"
# print(data[feature])

# %%
data.Traffic.max(),data.Traffic.min()
# Out:
# (13486.0, 0.0)

# %%
data[feature] = pd.to_numeric(data[feature], errors='coerce') 
# print(data.info())
data[feature]
# Out:
# 0        267388.65
# 1        668799.75
# 2        671177.75
# 3        265077.82
# 4        161678.91
#            ...
# 1032    1976177.99
# 1033    1211572.83
# 1034    1057772.56
# 1035    1353736.67
# 1036     778688.29
# Name: WrittenSales, Length: 1037, dtype: float64

# %%
bins = [-500000,250000,350000,500000,650000,900000, 3600000]
names = [1,2,3,4,5,6]

# %%
data["Range"] = pd.cut(data[feature], bins, labels=names)

data["Range"] = pd.Categorical(data["Range"]) 
print(data["Range"].unique())
# Out:
# [2, 5, 1, 3, 6, 4]
# Categories (6, int64): [1 < 2 < 3 < 4 < 5 < 6]

# %%
unique, counts = np.unique(data["Range"], return_counts=True)
plt.bar(unique, counts)

plt.title('Class Frequency')
plt.xlabel('Class')
plt.ylabel('Frequency')

plt.show()

# %%
data[feature].max(), data[feature].max()+1000
# Out:
# (3527566.77, 3528566.77)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
# data = data.dropna()
# data.isna().sum().sum()

# %%
data[["WrittenSales", "Range"]]
# Out:
#       WrittenSales Range
# 0        267388.65     2
# 1        668799.75     5
# 2        671177.75     5
# 3        265077.82     2
# 4        161678.91     1
# ...            ...   ...
# 1032    1976177.99     6
# 1033    1211572.83     6
# 1034    1057772.56     6
# 1035    1353736.67     6
# 1036     778688.29     5
#
# [1037 rows x 2 columns]

# %%
print(data["Range"].unique())
# Out:
# [2, 5, 1, 3, 6, 4]
# Categories (6, int64): [1 < 2 < 3 < 4 < 5 < 6]

# %% [markdown]
# # Train - Test Split

# %%
y = data.Range.astype(int).values

X = data.drop(["Date","Traffic","Margin", "WrittenSales","FinancedAmount","Range"],axis=1).values

X_df = data.drop(["Date","Traffic","Margin", "WrittenSales","FinancedAmount","Range"],axis=1)

# %%
y.shape,X.shape
# Out:
# ((1037,), (1037, 101))

# %%
# # %% train test split
from sklearn.model_selection import train_test_split
from collections import Counter

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state=100)

print(f"Training target statistics: {Counter(y_train)}")
print(f"Testing target statistics: {Counter(y_test)}")

print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Training target statistics: Counter({2: 150, 3: 130, 1: 120, 6: 118, 4: 105, 5: 102})
# Testing target statistics: Counter({2: 68, 3: 57, 1: 51, 6: 47, 4: 46, 5: 43})
# Number transactions X_train dataset:  (725, 101)
# Number transactions y_train dataset:  (725,)
# Number transactions X_test dataset:  (312, 101)
# Number transactions y_test dataset:  (312,)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Oversampling

# %%
# from imblearn.over_sampling import SMOTE

# print("Before OverSampling, counts of labels': {}".format(Counter(y_train)))

# oversample = SMOTE()
# X_train_res, y_train_res = oversample.fit_resample(X_train, y_train.ravel())

# %%
# print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
# print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

# print("After OverSampling, counts of label '1': {}".format(Counter(y_train_res)))

# %%
data[feature].max(),data["Range"].max()
# Out:
# (3527566.77, 6)

# %% [markdown]
# ## Applying PCA

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 2)
# X_train = pca.fit_transform(X_train)
# X_test = pca.transform(X_test)

# %% [markdown]
# # Grid Search - Imbalance

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, precision_recall_curve, accuracy_score, auc, roc_auc_score, roc_curve, recall_score, classification_report

from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
prediction.shape, X_test.shape, y_test.shape
# Out:
# ((312,), (312, 101), (312,))

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train) 

prediction = dt.predict(X_test)
print(" {} nn score: {} ".format(3,accuracy_score(y_test, prediction)))
# Out:
#  3 nn score: 0.47115384615384615

# %%
dt.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'random_state', 'splitter'])

# %%
param_dict = {
    "criterion":['gini','entropy'],
    "max_depth":range(1,10),
    "min_samples_split":range(1,10),
    "min_samples_leaf":range(1,5), 
    "max_features": range(1,len(X_df.columns)) # n_features_selected
}

# %%
clf = GridSearchCV(dt, 
                   param_grid = param_dict,
                   cv=5, verbose=5, n_jobs=3)
clf.fit(X_train, y_train.ravel())
# Out:
# Fitting 5 folds for each of 64800 candidates, totalling 324000 fits
# C:\Users\DKici\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan 0.24827586 0.21931034 ... 0.41517241 0.41517241 0.41241379]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=3,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 10),
#                          'max_features': range(1, 101),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 10)},
#              verbose=5)

# %%
clf.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 7,
#  'max_features': 42,
#  'min_samples_leaf': 4,
#  'min_samples_split': 8}

# %%
clf.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=42, min_samples_leaf=4,
#                        min_samples_split=8)

# %%
dt1 = DecisionTreeClassifier(**clf.best_params_)

dt1.fit(X_train, y_train.ravel())
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=42, min_samples_leaf=4,
#                        min_samples_split=8)

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    else:
        1#print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# X_train = X_train_res.T
# X_test = X_test.T
# y_train = y_train_res.T
# y_test = y_test.T

print("X_train: ",X_train.shape)
print("X_test: ",X_test.shape)
print("y_train: ",y_train.shape)
print("y_test: ",y_test.shape)
# Out:
# X_train:  (725, 101)
# X_test:  (312, 101)
# y_train:  (725,)
# y_test:  (312,)

# %%
y_train_pre = dt1.predict(X_train)

cnf_matrix_tra = confusion_matrix(y_train, y_train_pre)
class_names = [0,1,2,3,4,5,6]
plt.figure()
plot_confusion_matrix(cnf_matrix_tra , classes=class_names, title='Confusion matrix')
plt.show()

# %%
print(classification_report(y_train, dt1.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.51      0.60       120
#            2       0.40      0.78      0.53       150
#            3       0.56      0.42      0.48       130
#            4       0.56      0.43      0.49       105
#            5       0.55      0.44      0.49       102
#            6       0.88      0.64      0.75       118
#
#     accuracy                           0.55       725
#    macro avg       0.61      0.54      0.55       725
# weighted avg       0.61      0.55      0.55       725

# %%
y_pre = dt1.predict(X_test)

cnf_matrix = confusion_matrix(y_test, y_pre)
# Plot non-normalized confusion matrix
class_names = [0,1,2,3,4,5,6]
plt.figure()
plot_confusion_matrix(cnf_matrix , classes=class_names, title='Confusion matrix')
plt.show()

# %%
print(classification_report(y_test, dt1.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.74      0.45      0.56        51
#            2       0.40      0.84      0.54        68
#            3       0.46      0.32      0.37        57
#            4       0.32      0.24      0.28        46
#            5       0.26      0.21      0.23        43
#            6       0.67      0.43      0.52        47
#
#     accuracy                           0.44       312
#    macro avg       0.48      0.41      0.42       312
# weighted avg       0.48      0.44      0.43       312

# %%
# Set default font size
from sklearn import tree

plt.rcParams['font.size'] = 50
fig = plt.figure(figsize=(50,40))
_ = tree.plot_tree(dt1, 
                   feature_names=data.columns[1:-5],
                   class_names=["0","1","2","3","4","5","6"],
                   filled=True)

# %%
# fig.savefig("decision_tree.png")

# %%
importances = pd.DataFrame({'feature':data.columns[1:-5],'importance':np.round(dt1.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
importances
# Out:
#                                      feature  importance
# 76                           nth_day_of_week       0.203
# 85  Ontario_C6_Stay at home requirements_1.0       0.138
# 78                         month_of_the_year       0.121
# 98     Saskatchewan_C2_Workplace closing_3.0       0.084
# 77                          nth_day_of_month       0.081
# ..                                       ...         ...
# 32                        Amount % off in MB       0.000
# 31                       Amount % off in GTA       0.000
# 30                        Amount % off in AB       0.000
# 29                       Amount % Off at 090       0.000
# 50                              Matress Deal       0.000
#
# [101 rows x 2 columns]

# %%
# Set default font size
plt.rcParams['font.size'] = 14

plt.figure(figsize = (20,5))
sns.set_palette('mako')
plt.xticks(rotation = 90)
plt.title('Feature correlation')
sns.barplot (data = importances, x = "feature", y = 'importance');
